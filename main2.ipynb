# %%
import speech_recognition as sr
import pyttsx3
import pywhatkit
import datetime
import wikipedia
import pyjokes

listener = sr.Recognizer()
engine = pyttsx3.init()
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[1].id)


def talk(text):
    engine.say(text)
    engine.runAndWait()


def take_command():
    try:
        with sr.Microphone() as source:
            print('listening...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice)
            command = command.lower()
            if 'Jarvis' in command:
                command = command.replace('Jarvis', '')
                print(command)
    except:
        pass
    return command


def run_Jarvis():
    command = take_command()
    print(command)
    if 'play' in command:
        song = command.replace('play', '')
        talk('playing ' + song)
        pywhatkit.playonyt(song)
    elif 'stop' in command:
        talk('stopping')
        pywhatkit.stop()
    elif 'pause' in command:
        talk('pausing')
        pywhatkit.pause()
    elif 'resume' in command:
        talk('resuming')
        pywhatkit.resume()
    elif 'time' in command:
        time = datetime.datetime.now().strftime('%I:%M %p')
        talk('Current time is ' + time)
    elif 'date' in command:
        date = datetime.datetime.now().strftime('%d %B %Y')
        talk('Current date is ' + date)
    elif 'who is' in command:
        person = command.replace('who is', '')
        info = wikipedia.summary(person, 1)
        print(info)
        talk(info)
    elif 
    elif 'tell me a joke' in command:
        joke = pyjokes.get_joke()
        talk(joke)
    elif 'bye' in command:
        talk('bye')
        exit()
    else:
        talk('Sorry , I did not understand')
   
  






while True:
    run_Jarvis()
# Out:
# listening...
# open youtube
# listening...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# c:\Users\YASWANTH\Desktop\Vir ASSistant\main2.ipynb Cell 1' in <cell line: 91>()
#      <a href='vscode-notebook-cell:/c%3A/Users/YASWANTH/Desktop/Vir%20ASSistant/main2.ipynb#ch0000000?line=80'>81</a>         talk('Sorry , I did not understand')
#      <a href='vscode-notebook-cell:/c%3A/Users/YASWANTH/Desktop/Vir%20ASSistant/main2.ipynb#ch0000000?line=89'>90</a> while True:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/YASWANTH/Desktop/Vir%20ASSistant/main2.ipynb#ch0000000?line=90'>91</a>     run_Jarvis()
#
# c:\Users\YASWANTH\Desktop\Vir ASSistant\main2.ipynb Cell 1' in run_Jarvis()
#      <a href='vscode-notebook-cell:/c%3A/Users/YASWANTH/Desktop/Vir%20ASSistant/main2.ipynb#ch0000000?line=33'>34</a> def run_Jarvis():
# ---> <a href='vscode-notebook-cell:/c%3A/Users/YASWANTH/Desktop/Vir%20ASSistant/main2.ipynb#ch0000000?line=34'>35</a>     command = take_command()
#      <a href='vscode-notebook-cell:/c%3A/Users/YASWANTH/Desktop/Vir%20ASSistant/main2.ipynb#ch0000000?line=35'>36</a>     print(command)
#      <a href='vscode-notebook-cell:/c%3A/Users/YASWANTH/Desktop/Vir%20ASSistant/main2.ipynb#ch0000000?line=36'>37</a>     if 'play' in command:
#
# c:\Users\YASWANTH\Desktop\Vir ASSistant\main2.ipynb Cell 1' in take_command()
#      <a href='vscode-notebook-cell:/c%3A/Users/YASWANTH/Desktop/Vir%20ASSistant/main2.ipynb#ch0000000?line=28'>29</a> except:
#      <a href='vscode-notebook-cell:/c%3A/Users/YASWANTH/Desktop/Vir%20ASSistant/main2.ipynb#ch0000000?line=29'>30</a>     pass
# ---> <a href='vscode-notebook-cell:/c%3A/Users/YASWANTH/Desktop/Vir%20ASSistant/main2.ipynb#ch0000000?line=30'>31</a> return command
#
# UnboundLocalError: local variable 'command' referenced before assignment
